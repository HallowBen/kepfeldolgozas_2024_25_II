# %%
import numpy as np
import PIL

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision
import torchvision.models as models
import torchvision.transforms as transforms

import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader

import os

# %%
torch.cuda.is_available()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class DataProcess():
    def __init__(self, label_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(label_file, header=None)
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = PIL.Image.open(img_path)
        label = self.img_labels.iloc[idx, 1]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
train_data=DataProcess(label_file="./dataset/default/labels/TRAIN.csv",img_dir="./dataset/default/TRAIN/",transform=transform)
test_data=DataProcess(label_file="./dataset/default/labels/TEST.csv",img_dir="./dataset/default/TEST/",transform=transform)

# %%
train_loader= torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True, num_workers=0)
test_loader= torch.utils.data.DataLoader(test_data, batch_size=32, shuffle=False, num_workers=0)

# %%
resnet18 = models.resnet18()
resnet18.to(device=device)
resnet18.train()
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(resnet18.parameters(), lr=0.003, momentum=0.9)

# %%
def test(best):
    test=models.resnet18()
    test.to(device)
    test.load_state_dict(torch.load("./models/resnet18/default_last.pt", weights_only=True))
    test.eval()
    total=0
    correct=0
    with torch.no_grad():
        for i, data in enumerate(test_loader):
            images_test, labels_test = data
            images_test, labels_test = images_test.to(device), labels_test.to(device)
            outputs=test(images_test)
            _, predicts = torch.max(outputs, 1)

            total += labels_test.size(0)

            correct += (predicts==labels_test).sum().item()
        
        accuracy = 100*correct/total
        
        if best < accuracy:
            torch.save(test.state_dict(), "./models/resnet18/default_best.pt")
        
        print(f'Accuracy: {accuracy}%')

    return accuracy

# %%
def train():
    running_loss = 0.0
    for i, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        output = resnet18(inputs)
        # print(output[0].size())
        loss = loss_function(output, labels)
        loss.backward()
        optimizer.step()

    running_loss += loss.item()

    print(f'Loss: {running_loss / len(train_loader): .4f}')

    torch.save(resnet18.state_dict(), "./models/resnet18/default_last.pt")

# %%
best=0
EPOCH=60
for epoch in range(EPOCH):
    print(f'Training epoch {epoch}...')

    train()

    last=test(best)
    if best < last:
        best=last
# Out:
# Training epoch 0...
# Loss:  0.0214
# Accuracy: 25.46082949308756%
# Training epoch 1...
# Loss:  0.0169
# Accuracy: 44.75806451612903%
# Training epoch 2...
# Loss:  0.0447
# Accuracy: 55.24193548387097%
# Training epoch 3...
# Loss:  0.0455
# Accuracy: 57.085253456221196%
# Training epoch 4...
# Loss:  0.0123
# Accuracy: 64.8041474654378%
# Training epoch 5...
# Loss:  0.0357
# Accuracy: 65.09216589861751%
# Training epoch 6...
# Loss:  0.0595
# Accuracy: 62.096774193548384%
# Training epoch 7...
# Loss:  0.0059
# Accuracy: 67.10829493087557%
# Training epoch 8...
# Loss:  0.0630
# Accuracy: 82.20046082949308%
# Training epoch 9...
# Loss:  0.0415
# Accuracy: 89.34331797235023%
# Training epoch 10...
# Loss:  0.0310
# Accuracy: 83.92857142857143%
# Training epoch 11...
# Loss:  0.0065
# Accuracy: 83.81336405529954%
# Training epoch 12...
# Loss:  0.0029
# Accuracy: 95.44930875576037%
# Training epoch 13...
# Loss:  0.0048
# Accuracy: 93.26036866359448%
# Training epoch 14...
# Loss:  0.0027
# Accuracy: 96.54377880184332%
# Training epoch 15...
# Loss:  0.0030
# Accuracy: 98.32949308755761%
# Training epoch 16...
# Loss:  0.0524
# Accuracy: 84.38940092165899%
# Training epoch 17...
# Loss:  0.0534
# Accuracy: 88.82488479262673%
# Training epoch 18...
# Loss:  0.0385
# Accuracy: 74.13594470046083%
# Training epoch 19...
# Loss:  0.0329
# Accuracy: 91.58986175115207%
# Training epoch 20...
# Loss:  0.0297
# Accuracy: 83.41013824884793%
# Training epoch 21...
# Loss:  0.0255
# Accuracy: 97.35023041474655%
# Training epoch 22...
# Loss:  0.0391
# Accuracy: 95.85253456221199%
# Training epoch 23...
# Loss:  0.0041
# Accuracy: 77.53456221198157%
# Training epoch 24...
# Loss:  0.0381
# Accuracy: 97.63824884792626%
# Training epoch 25...
# Loss:  0.0356
# Accuracy: 95.16129032258064%
# Training epoch 26...
# Loss:  0.0221
# Accuracy: 97.6958525345622%
# Training epoch 27...
# Loss:  0.0467
# Accuracy: 91.82027649769586%
# Training epoch 28...
# Loss:  0.0448
# Accuracy: 78.51382488479263%
# Training epoch 29...
# Loss:  0.0230
# Accuracy: 91.12903225806451%
# Training epoch 30...
# Loss:  0.0025
# Accuracy: 95.56451612903226%
# Training epoch 31...
# Loss:  0.0387
# Accuracy: 96.88940092165899%
# Training epoch 32...
# Loss:  0.0019
# Accuracy: 69.00921658986175%
# Training epoch 33...
# Loss:  0.0027
# Accuracy: 97.86866359447005%
# Training epoch 34...
# Loss:  0.0509
# Accuracy: 97.98387096774194%
# Training epoch 35...
# Loss:  0.0159
# Accuracy: 96.6589861751152%
# Training epoch 36...
# Loss:  0.0634
# Accuracy: 92.97235023041475%
# Training epoch 37...
# Loss:  0.0021
# Accuracy: 85.71428571428571%
# Training epoch 38...
# Loss:  0.0367
# Accuracy: 96.54377880184332%
# Training epoch 39...
# Loss:  0.0496
# Accuracy: 95.50691244239631%
# Training epoch 40...
# Loss:  0.0531
# Accuracy: 96.83179723502305%
# Training epoch 41...
# Loss:  0.0189
# Accuracy: 96.1405529953917%
# Training epoch 42...
# Loss:  0.0443
# Accuracy: 92.22350230414746%
# Training epoch 43...
# Loss:  0.0378
# Accuracy: 93.54838709677419%
# Training epoch 44...
# Loss:  0.0789
# Accuracy: 89.91935483870968%
# Training epoch 45...
# Loss:  0.0009
# Accuracy: 96.02534562211981%
# Training epoch 46...
# Loss:  0.0012
# Accuracy: 98.04147465437788%
# Training epoch 47...
# Loss:  0.0630
# Accuracy: 97.6958525345622%
# Training epoch 48...
# Loss:  0.0170
# Accuracy: 96.2557603686636%
# Training epoch 49...
# Loss:  0.0512
# Accuracy: 96.83179723502305%
# Training epoch 50...
# Loss:  0.0816
# Accuracy: 96.94700460829493%
# Training epoch 51...
# Loss:  0.0003
# Accuracy: 97.11981566820276%
# Training epoch 52...
# Loss:  0.0773
# Accuracy: 98.38709677419355%
# Training epoch 53...
# Loss:  0.0172
# Accuracy: 94.47004608294931%
# Training epoch 54...
# Loss:  0.0188
# Accuracy: 96.1405529953917%
# Training epoch 55...
# Loss:  0.0329
# Accuracy: 92.3963133640553%
# Training epoch 56...
# Loss:  0.0436
# Accuracy: 92.79953917050692%
# Training epoch 57...
# Loss:  0.0637
# Accuracy: 96.1405529953917%
# Training epoch 58...
# Loss:  0.0000
# Accuracy: 97.1774193548387%
# Training epoch 59...
# Loss:  0.0378
# Accuracy: 97.1774193548387%

# %%
validate_defult=DataProcess(label_file="./dataset/default/labels/VALIDATE.csv",img_dir="./dataset/default/VALIDATE/",transform=transform)
validate_defult_loader= torch.utils.data.DataLoader(validate_defult, batch_size=10, shuffle=False, num_workers=0)
validate_no_bg=DataProcess(label_file="./dataset/no_bg/labels/VALIDATE.csv",img_dir="./dataset/no_bg/VALIDATE/",transform=transform)
validate_no_bg_loader= torch.utils.data.DataLoader(validate_no_bg, batch_size=10, shuffle=False, num_workers=0)
validate_random_bg=DataProcess(label_file="./dataset/random_bg/labels/VALIDATE.csv",img_dir="./dataset/random_bg/VALIDATE/",transform=transform)
validate_random_bg_loader= torch.utils.data.DataLoader(validate_random_bg, batch_size=10, shuffle=False, num_workers=0)

validate_loaders=[validate_defult_loader,validate_no_bg_loader,validate_random_bg_loader]

# %%
def validate(loader: torch.utils.data.DataLoader):
    validate_model = models.resnet18()
    validate_model.to(device)
    validate_model.load_state_dict(torch.load("./models/resnet18/default_best.pt", weights_only=True))
    validate_model.eval()
    total=0
    correct=0
    with torch.no_grad():
        for data in loader:
            image, label =data
            image, label = image.to(device), label.to(device)
            outputs=validate_model(image)
            _, predicts = torch.max(outputs, 1)

            total += label.size(0)

            correct += (predicts==label).sum().item()
        
        accuracy = 100*correct/total
        print(f'Accuracy: {accuracy: .4f}')

# %%
for loader in validate_loaders:
    validate(loader)
# Out:
# Accuracy:  98.8145
# Accuracy:  26.9596
# Accuracy:  36.4889
