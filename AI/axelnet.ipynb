# %%
import numpy as np
import PIL

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision
import torchvision.models as models
import torchvision.transforms as transforms

import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader

import os

# %%
torch.cuda.is_available()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
FOLDERS=["default","no_bg","random_bg"]

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class DataProcess():
    def __init__(self, label_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(label_file, header=None)
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = PIL.Image.open(img_path)
        label = self.img_labels.iloc[idx, 1]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
alexnet = models.alexnet()
alexnet.to(device=device)
alexnet.train()
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(alexnet.parameters(), lr=0.003, momentum=0.9)

# %%
def reset():
    global alexnet, loss_function, optimizer
    alexnet = models.alexnet()
    alexnet.to(device=device)
    alexnet.train()
    loss_function = nn.CrossEntropyLoss()
    optimizer = optim.SGD(alexnet.parameters(), lr=0.003, momentum=0.9)

# %%
def test(best, name, test_loader):
    test=models.alexnet()
    test.to(device)
    test.load_state_dict(torch.load("./models/alexnet/"+name+"_last.pt", weights_only=True))
    test.eval()
    total=0
    correct=0
    with torch.no_grad():
        for i, data in enumerate(test_loader):
            images_test, labels_test = data
            images_test, labels_test = images_test.to(device), labels_test.to(device)
            outputs=test(images_test)
            _, predicts = torch.max(outputs, 1)

            total += labels_test.size(0)

            correct += (predicts==labels_test).sum().item()
        
        accuracy = 100*correct/total
        
        if best < accuracy:
            torch.save(test.state_dict(), "./models/alexnet/"+name+"_best.pt")
        
        print(f'Accuracy: {accuracy}%')

    return accuracy

# %%
def train(name, train_loader):
    running_loss = 0.0
    for i, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        output = alexnet(inputs)
        # print(output[0].size())
        loss = loss_function(output, labels)
        loss.backward()
        optimizer.step()

    running_loss += loss.item()

    print(f'Loss: {running_loss / len(train_loader): .4f}')

    torch.save(alexnet.state_dict(), "./models/alexnet/"+name+"_last.pt")

# %%
for name in FOLDERS:
    reset()
    train_data=DataProcess(label_file="./dataset/"+name+"/labels/TRAIN.csv",img_dir="./dataset/"+name+"/TRAIN/",transform=transform)
    test_data=DataProcess(label_file="./dataset/"+name+"/labels/TEST.csv",img_dir="./dataset/"+name+"/TEST/",transform=transform)
    train_loader= torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True, num_workers=0)
    test_loader= torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=False, num_workers=0)
    best=0
    EPOCH=60
    for epoch in range(EPOCH):
        print(f'Training epoch {epoch}...')

        train( name, train_loader)

        last=test(best, name, test_loader)
        if best < last:
            best=last
# Out:
# Training epoch 0...
# Loss:  0.1043
# Accuracy: 26.726726726726728%
# Training epoch 1...
# Loss:  0.0131
# Accuracy: 32.972972972972975%
# Training epoch 2...
# Loss:  0.0348
# Training epoch 21...
# Loss:  0.0018
# Accuracy: 96.7930029154519%
# Training epoch 22...
# Loss:  0.0007
# Accuracy: 98.83381924198251%
# Training epoch 23...
# Loss:  0.0004
# Accuracy: 98.95043731778425%
# Training epoch 24...
# Loss:  0.0030
# Accuracy: 98.25072886297376%
# Training epoch 25...
# Loss:  0.0001
# Accuracy: 98.30903790087464%
# Training epoch 26...
# Loss:  0.0032
# Accuracy: 98.600583090379%
# Training epoch 27...
# Loss:  0.0001
# Accuracy: 99.59183673469387%
# Training epoch 28...
# Loss:  0.0001
# Accuracy: 98.48396501457727%
# Training epoch 29...
# Loss:  0.0050
# Accuracy: 99.59183673469387%
# Training epoch 30...
# Loss:  0.0000
# Accuracy: 98.01749271137027%
# Training epoch 31...
# Loss:  0.0003
# Accuracy: 99.067055393586%
# Training epoch 32...
# Loss:  0.0019
# Accuracy: 99.59183673469387%
# Training epoch 33...
# Loss:  0.0023
# Accuracy: 99.18367346938776%
# Training epoch 34...
# Loss:  0.0002
# Accuracy: 99.47521865889213%
# Training epoch 35...
# Loss:  0.0000
# Accuracy: 99.76676384839651%
# Training epoch 36...
# Loss:  0.0002
# Accuracy: 99.94169096209913%
# Training epoch 37...
# Loss:  0.0003
# Accuracy: 99.88338192419825%
# Training epoch 38...
# Loss:  0.0000
# Accuracy: 99.76676384839651%
# Training epoch 39...
# Loss:  0.0001
# Accuracy: 100.0%
# Training epoch 40...
# Loss:  0.0000
# Accuracy: 99.94169096209913%
# Training epoch 41...
# Loss:  0.0001
# Accuracy: 98.54227405247813%
# Training epoch 42...
# Loss:  0.0008
# Accuracy: 100.0%
# Training epoch 43...
# Loss:  0.0000
# Accuracy: 99.70845481049562%
# Training epoch 44...
# Loss:  0.0023
# Accuracy: 99.94169096209913%
# Training epoch 45...
# Loss:  0.0003
# Accuracy: 98.95043731778425%
# Training epoch 46...
# Loss:  0.0000
# Accuracy: 99.76676384839651%
# Training epoch 47...
# Loss:  0.0012
# Accuracy: 98.95043731778425%
# Training epoch 48...
# Loss:  0.0001
# Accuracy: 100.0%
# Training epoch 49...
# Loss:  0.0000
# Accuracy: 100.0%
# Training epoch 50...
# Loss:  0.0000
# Accuracy: 100.0%
# Training epoch 51...
# Loss:  0.0003
# Accuracy: 100.0%
# Training epoch 52...
# Loss:  0.0000
# Accuracy: 100.0%
# Training epoch 53...
# Loss:  0.0000
# Accuracy: 100.0%
# Training epoch 54...
# Loss:  0.0000
# Accuracy: 100.0%
# Training epoch 55...
# Loss:  0.0018
# Accuracy: 99.47521865889213%
# Training epoch 56...
# Loss:  0.0000
# Accuracy: 99.82507288629738%
# Training epoch 57...
# Loss:  0.0000
# Accuracy: 100.0%
# Training epoch 58...
# Loss:  0.0000
# Accuracy: 100.0%
# Training epoch 59...
# Loss:  0.0000
# Accuracy: 100.0%
# Training epoch 0...
# Loss:  0.1015
# Accuracy: 25.853094274146905%
# Training epoch 1...
# Loss:  0.0191
# Accuracy: 25.21688837478311%
# Training epoch 2...
# Loss:  0.0213
# Accuracy: 23.655292076344708%
# Training epoch 3...
# Loss:  0.0199
# Accuracy: 25.21688837478311%
# Training epoch 4...
# Loss:  0.0280
# Accuracy: 25.274725274725274%
# Training epoch 5...
# Loss:  0.0225
# Accuracy: 25.274725274725274%
# Training epoch 6...
# Loss:  0.0289
# Accuracy: 23.655292076344708%
# Training epoch 7...
# Loss:  0.0200
# Accuracy: 25.21688837478311%
# Training epoch 8...
# Loss:  0.0275
# Accuracy: 23.655292076344708%
# Training epoch 9...
# Loss:  0.0262
# Accuracy: 23.655292076344708%
# Training epoch 10...
# Loss:  0.0258
# Accuracy: 31.925968768074032%
# Training epoch 11...
# Loss:  0.0242
# Accuracy: 25.853094274146905%
# Training epoch 12...
# Loss:  0.0241
# Accuracy: 25.274725274725274%
# Training epoch 13...
# Loss:  0.0239
# Accuracy: 25.853094274146905%
# Training epoch 14...
# Loss:  0.0209
# Accuracy: 25.21688837478311%
# Training epoch 15...
# Loss:  0.0258
# Accuracy: 23.655292076344708%
# Training epoch 16...
# Loss:  0.0261
# Accuracy: 25.274725274725274%
# Training epoch 17...
# Loss:  0.0258
# Accuracy: 23.655292076344708%
# Training epoch 18...
# Loss:  0.0225
# Accuracy: 25.21688837478311%
# Training epoch 19...
# Loss:  0.0234
# Accuracy: 25.853094274146905%
# Training epoch 20...
# Loss:  0.0225
# Accuracy: 23.655292076344708%
# Training epoch 21...
# Loss:  0.0244
# Accuracy: 25.21688837478311%
# Training epoch 22...
# Loss:  0.0306
# Accuracy: 24.002313475997685%
# Training epoch 23...
# Loss:  0.0221
# Accuracy: 25.274725274725274%
# Training epoch 24...
# Loss:  0.0196
# Accuracy: 25.853094274146905%
# Training epoch 25...
# Loss:  0.0271
# Accuracy: 25.274725274725274%
# Training epoch 26...
# Loss:  0.0239
# Accuracy: 33.77674956622325%
# Training epoch 27...
# Loss:  0.0254
# Accuracy: 33.37189126662811%
# Training epoch 28...
# Loss:  0.0199
# Accuracy: 41.98958935801041%
# Training epoch 29...
# Loss:  0.0225
# Accuracy: 44.30306535569694%
# Training epoch 30...
# Loss:  0.0167
# Accuracy: 45.575477154424526%
# Training epoch 31...
# Loss:  0.0158
# Accuracy: 55.176402544823596%
# Training epoch 32...
# Loss:  0.0082
# Accuracy: 49.50838635049161%
# Training epoch 33...
# Loss:  0.0153
# Accuracy: 59.3984962406015%
# Training epoch 34...
# Loss:  0.0033
# Accuracy: 66.85945633314054%
# Training epoch 35...
# Loss:  0.0107
# Accuracy: 62.174667437825335%
# Training epoch 36...
# Loss:  0.0323
# Accuracy: 63.67842683632157%
# Training epoch 37...
# Loss:  0.0014
# Accuracy: 72.35396182764603%
# Training epoch 38...
# Loss:  0.0001
# Accuracy: 75.82417582417582%
# Training epoch 39...
# Loss:  0.0023
# Accuracy: 76.22903412377097%
# Training epoch 40...
# Loss:  0.0063
# Accuracy: 85.36726431463273%
# Training epoch 41...
# Loss:  0.0001
# Accuracy: 88.89531521110469%
# Training epoch 42...
# Loss:  0.0067
# Accuracy: 84.73105841526895%
# Training epoch 43...
# Loss:  0.0007
# Accuracy: 92.53903990746096%
# Training epoch 44...
# Loss:  0.0532
# Accuracy: 90.39907460960093%
# Training epoch 45...
# Loss:  0.0034
# Accuracy: 92.42336610757664%
# Training epoch 46...
# Loss:  0.0042
# Accuracy: 92.88606130711393%
# Training epoch 47...
# Loss:  0.0000
# Accuracy: 96.64545980335454%
# Training epoch 48...
# Loss:  0.0000
# Accuracy: 89.47368421052632%
# Training epoch 49...
# Loss:  0.0001
# Accuracy: 95.89358010410642%
# Training epoch 50...
# Loss:  0.0016
# Accuracy: 96.06709080393291%
# Training epoch 51...
# Loss:  0.0012
# Accuracy: 96.7032967032967%
# Training epoch 52...
# Loss:  0.0000
# Accuracy: 98.49624060150376%
# Training epoch 53...
# Loss:  0.0054
# Accuracy: 96.29843840370157%
# Training epoch 54...
# Loss:  0.0000
# Accuracy: 98.09138230190862%
# Training epoch 55...
# Loss:  0.0000
# Accuracy: 95.37304800462695%
# Training epoch 56...
# Loss:  0.0001
# Accuracy: 97.28166570271833%
# Training epoch 57...
# Loss:  0.0000
# Accuracy: 95.19953730480046%
# Training epoch 58...
# Loss:  0.0000
# Accuracy: 99.71081550028919%
# Training epoch 59...
# Loss:  0.0000
# Accuracy: 99.94216310005784%

# %%
validate_defult=DataProcess(label_file="./dataset/default/labels/VALIDATE.csv",img_dir="./dataset/default/VALIDATE/",transform=transform)
validate_defult_loader= torch.utils.data.DataLoader(validate_defult, batch_size=10, shuffle=False, num_workers=0)
validate_no_bg=DataProcess(label_file="./dataset/no_bg/labels/VALIDATE.csv",img_dir="./dataset/no_bg/VALIDATE/",transform=transform)
validate_no_bg_loader= torch.utils.data.DataLoader(validate_no_bg, batch_size=10, shuffle=False, num_workers=0)
validate_random_bg=DataProcess(label_file="./dataset/random_bg/labels/VALIDATE.csv",img_dir="./dataset/random_bg/VALIDATE/",transform=transform)
validate_random_bg_loader= torch.utils.data.DataLoader(validate_random_bg, batch_size=10, shuffle=False, num_workers=0)

validate_loaders=[validate_defult_loader,validate_no_bg_loader,validate_random_bg_loader]

# %%
def validate(loader: torch.utils.data.DataLoader):
    validate_model = models.alexnet()
    validate_model.to(device)
    validate_model.load_state_dict(torch.load("./models/alexnet/random_bg_best.pt", weights_only=True))
    validate_model.eval()
    total=0
    correct=0
    with torch.no_grad():
        for data in loader:
            image, label =data
            image, label = image.to(device), label.to(device)
            outputs=validate_model(image)
            _, predicts = torch.max(outputs, 1)

            total += label.size(0)

            correct += (predicts==label).sum().item()
        
        accuracy = 100*correct/total
        print(f'Accuracy: {accuracy: .4f}')

# %%
for loader in validate_loaders:
    validate(loader)
# Out:
# Accuracy:  64.8488
# Accuracy:  74.6437
# Accuracy:  94.4877
